# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('pet_supplies_2212.csv')
print('Data read into a pandas dataframe!')
df
# Out:
# Data read into a pandas dataframe!
#       product_id   category animal    size  price    sales  rating  \
# 0              1       Food   Bird   large   51.1  1860.62     7.0
# 1              2    Housing   Bird  MEDIUM  35.98   963.60     6.0
# 2              3       Food    Dog  medium  31.23   898.30     5.0
# 3              4   Medicine    Cat   small  24.95   982.15     6.0
# 4              5    Housing    Cat   Small  26.18   832.63     7.0
# ...          ...        ...    ...     ...    ...      ...     ...
# 1495        1496       Food   Bird  medium  40.91  1203.36     5.0
# 1496        1497  Equipment    Dog   small  32.89  1099.97     5.0
# 1497        1498       Food   Fish   Small  25.79   724.02     3.0
# 1498        1499   Medicine   Fish   small  19.94   658.66     5.0
# 1499        1500       Food    Cat  Medium  25.95   826.08     4.0
#
#       repeat_purchase
# 0                   1
# 1                   0
# 2                   1
# 3                   1
# ...

# %% [markdown]
# View the top 5 rows of the dataset using the `head()` function.

# %%
df.head()
# Out:
#    product_id  category animal    size  price    sales  rating  \
# 0           1      Food   Bird   large   51.1  1860.62     7.0
# 1           2   Housing   Bird  MEDIUM  35.98   963.60     6.0
# 2           3      Food    Dog  medium  31.23   898.30     5.0
# 3           4  Medicine    Cat   small  24.95   982.15     6.0
# 4           5   Housing    Cat   Small  26.18   832.63     7.0
#
#    repeat_purchase
# 0                1
# 1                0
# 2                1
# 3                1
# 4                1

# %% [markdown]
# View the last 5 rows of the dataset using the `tail()` function.

# %%
df.tail()
# Out:
#       product_id   category animal    size  price    sales  rating  \
# 1495        1496       Food   Bird  medium  40.91  1203.36     5.0
# 1496        1497  Equipment    Dog   small  32.89  1099.97     5.0
# 1497        1498       Food   Fish   Small  25.79   724.02     3.0
# 1498        1499   Medicine   Fish   small  19.94   658.66     5.0
# 1499        1500       Food    Cat  Medium  25.95   826.08     4.0
#
#       repeat_purchase
# 1495                0
# 1496                0
# 1497                0
# 1498                1
# 1499                1

# %% [markdown]
# Use the `info()` method to get a short summary of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   product_id       1500 non-null   int64
#  1   category         1500 non-null   object
#  2   animal           1500 non-null   object
#  3   size             1500 non-null   object
#  4   price            1500 non-null   object
#  5   sales            1500 non-null   float64
#  6   rating           1350 non-null   float64
#  7   repeat_purchase  1500 non-null   int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 93.9+ KB

# %% [markdown]
# View a quick summary of the numerical attributes using the `describe()` method.

# %%
df.describe()
# Out:
#         product_id        sales       rating  repeat_purchase
# count  1500.000000  1500.000000  1350.000000      1500.000000
# mean    750.500000   996.597847     4.991111         0.604000
# std     433.157015   323.952676     1.559755         0.489228
# min       1.000000   286.940000     1.000000         0.000000
# 25%     375.750000   747.420000     4.000000         0.000000
# 50%     750.500000  1000.830000     5.000000         1.000000
# 75%    1125.250000  1158.157500     6.000000         1.000000
# max    1500.000000  2255.960000     9.000000         1.000000

# %% [markdown]
# ## Task 1

# %% [markdown]
# Check the number of the null values in each column using the `isnull()` method.

# %%
null_values = df.isnull().sum()
null_values
# Out:
# product_id           0
# category             0
# animal               0
# size                 0
# price                0
# sales                0
# rating             150
# repeat_purchase      0
# dtype: int64

# %% [markdown]
# #### 'animal' column

# %%
value_counts = df['animal'].value_counts()
plt.figure(figsize=(8, 6))
value_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of values in animal column')
plt.xlabel('Animal')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### 'rating' column

# %%
value_counts = df['rating'].value_counts()
plt.figure(figsize=(8, 6))
value_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of values in rating column')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.show()

# %%
df['rating'].isnull().sum()
# Out:
# 150

# %% [markdown]
# As you can see, there are 150 values in the 'rating' column, so that we replace the null values with 0.

# %%
df['rating'].fillna(0, inplace=True)

# %% [markdown]
# Then, recheck the number of the null values in the 'rating' column.

# %%
df['rating'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 'repeat_purchase' column

# %%
value_counts = df['repeat_purchase'].value_counts()
plt.figure(figsize=(8, 6))
value_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of values in repeat purchase column')
plt.xlabel('Repeat Purchase')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### 'category' column

# %%
value_counts = df['category'].value_counts()
plt.figure(figsize=(8, 6))
value_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of values in category column')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Because the column which contains the '-' value account 10% for the total values of the column, we will place that column with the 'Unknown' value.A

# %%
df['category'] = df['category'].replace('-', 'Unknown')

# %% [markdown]
# Recheck the 'category' column to make sure that there is no '-' value.

# %%
value_counts = df['category'].value_counts()
plt.figure(figsize=(8, 6))
value_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of values in category column')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### 'size' column

# %% [markdown]
# Use the `unique()` method to check the unique values in the 'size' column.

# %%
np.unique(df['size'])
# Out:
# array(['LARGE', 'Large', 'MEDIUM', 'Medium', 'SMALL', 'Small', 'large',
#        'medium', 'small'], dtype=object)

# %% [markdown]
# As we can see, there are 3 main different values in the 'size' column: 'small', 'medium', 'large'. We will replace them with other values.

# %%
df['size'] = df['size'].str.lower()

# %% [markdown]
# Recheck the 'size' column to make sure that there is no un-formatted value.

# %%
value_counts = df['size'].value_counts()
plt.figure(figsize=(8, 6))
value_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of values in size column')
plt.xlabel('Size')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## Task 2

# %%
df_task2 = df[['category', 'repeat_purchase']]
df_task2
# Out:
#        category  repeat_purchase
# 0          Food                1
# 1       Housing                0
# 2          Food                1
# 3      Medicine                1
# 4       Housing                1
# ...         ...              ...
# 1495       Food                0
# 1496  Equipment                0
# 1497       Food                0
# 1498   Medicine                1
# 1499       Food                1
#
# [1500 rows x 2 columns]

# %%
df_task2 = df_task2.groupby(['category', 'repeat_purchase']).size()
df_task2
# Out:
# category   repeat_purchase
# Accessory  0                   56
#            1                   70
# Equipment  0                  149
#            1                  221
# Food       0                  109
#            1                  151
# Housing    0                   75
#            1                  152
# Medicine   0                   84
#            1                  153
# Toys       0                  110
#            1                  145
# Unknown    0                   11
#            1                   14
# dtype: int64

# %% [markdown]
# Create a visualization that shows how many products are repeate purchased has the most observations.

# %%
# Reshape the data for plotting
df_plot = df_task2.unstack().fillna(0)

# Create a stacked bar chart
ax = df_plot.plot(kind='bar', stacked=True, figsize=(10, 6))

# Add labels and title
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Counts of Repeat Purchases by Category')

# Add a legend
plt.legend(title='Repeat Purchase', labels=['No', 'Yes'], loc='upper right')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
total_counts = df_task2.groupby('repeat_purchase').sum()
total_counts
# Out:
# repeat_purchase
# 0    594
# 1    906
# dtype: int64

# %% [markdown]
# In this case, "0" typically represents cases where there was no repeat purchase, and "1" represents cases where there was a repeat purchase. To assess balance or imbalance:
#
# **Looking at the Total Counts:**
#
#    - The total count of "0" values is 594.
#    - The total count of "1" values is 906.
#
#    There are more observations with "1" (repeat purchases) than "0" (non-repeat purchases) across all categories. This suggests an imbalance in favor of repeat purchases overall.
#
# **Looking at Individual Categories:**
#
#    When we examine the individual categories:
#    - For "Accessory," there are 56 observations with "0" and 70 with "1," which is relatively balanced.
#    - For "Equipment," there are 149 observations with "0" and 221 with "1," which is imbalanced in favor of repeat purchases.
#    - For "Food," there are 109 observations with "0" and 151 with "1," which is also imbalanced in favor of repeat purchases.
#    - For "Housing," there are 75 observations with "0" and 152 with "1," which is imbalanced in favor of repeat purchases.
#    - For "Medicine," there are 84 observations with "0" and 153 with "1," which is imbalanced in favor of repeat purchases.
#    - For "Toys," there are 110 observations with "0" and 145 with "1," which is relatively balanced.
#    - For "Unknown," there are 11 observations with "0" and 14 with "1," which is also relatively balanced.
#
# **Overall Assessment:**
#
#    The imbalance or balance in the "repeat_purchase" variable across different categories depends on the specific category. Some categories are more balanced, while others are imbalanced in favor of repeat purchases. The total dataset is also imbalanced, as there are more "1" values (repeat purchases) than "0" values (non-repeat purchases) overall.
#
#    Whether this imbalance is a concern depends on the context of your analysis and the specific goals of your project. Imbalanced data can sometimes impact the performance of machine learning models or statistical analyses, so it's important to consider this when choosing analytical methods or making decisions based on this data.

# %% [markdown]
# ## Task 3

# %% [markdown]
# Calculate the basic statistics of the 'sales' column.

# %%
sales_stats = df['sales'].describe()
sales_stats
# Out:
# count    1500.000000
# mean      996.597847
# std       323.952676
# min       286.940000
# 25%       747.420000
# 50%      1000.830000
# 75%      1158.157500
# max      2255.960000
# Name: sales, dtype: float64

# %% [markdown]
# Create a box plot of the `sales` column

# %%
sns.boxplot(x=df['sales'])
plt.xlabel('Sales')
plt.title('Box Plot of Sales')
plt.show()

# %% [markdown]
# The box plot show that the distribution of the 'sales' column from around 750 to approximately 1100. However, there are some outliers in the 'sales' column.

# %% [markdown]
# Create a histogram of the `sales` column

# %%
plt.hist(df['sales'], bins=20, edgecolor='k')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Distribution of Sales')
plt.show()

# %% [markdown]
# The histogram shows that the distribution of the 'sales' column is right-skewed. The majority of the values are between 750 and 1100, with a few outliers above 1750.

# %% [markdown]
# ## Task 4

# %%
df_task4 = df[['sales', 'repeat_purchase']]
df_task4
# Out:
#         sales  repeat_purchase
# 0     1860.62                1
# 1      963.60                0
# 2      898.30                1
# 3      982.15                1
# 4      832.63                1
# ...       ...              ...
# 1495  1203.36                0
# 1496  1099.97                0
# 1497   724.02                0
# 1498   658.66                1
# 1499   826.08                1
#
# [1500 rows x 2 columns]

# %%
sale_counts = df_task4.groupby('repeat_purchase').sum()
sale_counts
# Out:
#                      sales
# repeat_purchase
# 0                610850.60
# 1                884046.17

# %% [markdown]
# Bar chart of the `category` and `repeat_purchase` columns

# %%
repeat_purchase_counts = sale_counts.index
sales_0 = sale_counts.loc[0]['sales']
sales_1 = sale_counts.loc[1]['sales']

# Create a stacked bar chart
plt.figure(figsize=(8, 6))
plt.bar(repeat_purchase_counts, [
        sales_0, sales_1], color=['skyblue', 'lightcoral'])
plt.xlabel('Repeat Purchase')
plt.ylabel('Total Sales')
plt.title('Total Sales by Repeat Purchase')
plt.xticks(repeat_purchase_counts, ['No', 'Yes'])
plt.show()

# %% [markdown]
# Based on the provided data and calculations:
#
# - For products with a "repeat_purchase" value of 0, the total sales amount is $610,850.60.
# - For products with a "repeat_purchase" value of 1, the total sales amount is $884,046.17.
#
# We can observe the following relationship between repeat purchase and sales:
#
# Products with a "repeat_purchase" value of 1 (meaning they were repeat-purchased) have a higher total sales amount ($884,046.17) compared to products with a "repeat_purchase" value of 0 ($610,850.60). This suggests that products that are more likely to be repeat-purchased tend to generate higher sales revenue.
#
# In other words, there appears to be a positive relationship between repeat purchases and sales, indicating that products that customers are more likely to repurchase contribute more to the total sales revenue. This information could be valuable for understanding customer behavior and making decisions related to product offerings and marketing strategies.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
